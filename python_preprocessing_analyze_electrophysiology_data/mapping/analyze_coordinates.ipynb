# %%
import scipy.io
import numpy as np
import pandas as pd
from skspatial.objects import Line
from skspatial.objects import Points

# %%
directory = r'C:\Users\shirahad\Documents\research\electrophysiology\analyze_electrophysiology_data\mapping\files'

# %%
probe_coordinates = scipy.io.loadmat(os.path.join(directory, 'probe_points_electrode_track.mat'))
channel_positions = np.load(os.path.join(directory, 'channel_positions.npy'))
channel_map = np.load(os.path.join(directory, 'channel_map.npy'))
clusters_data_df = pd.read_csv(os.path.join(directory, 'cluster_info.tsv'), sep="\t", header=0, index_col=0)

# %%
channel_positions
# Out:
# array([[ 43.3, 775. ],
#        [ 43.3, 675. ],
#        [ 43.3, 475. ],
#        [ 43.3, 375. ],
#        [ 43.3, 325. ],
#        [ 43.3, 125. ],
#        [ 43.3, 725. ],
#        [ 43.3,  25. ],
#        [  0. ,  50. ],
#        [  0. , 300. ],
#        [  0. , 150. ],
#        [  0. , 700. ],
#        [  0. , 500. ],
#        [  0. , 350. ],
#        [  0. , 650. ],
#        [  0. , 200. ],
#        [ 43.3, 225. ],
#        [ 43.3, 275. ],
#        [ 43.3, 575. ],
#        [ 43.3, 525. ],
#        [ 43.3, 425. ],
#        [ 43.3, 175. ],
#        [ 43.3, 625. ],
#        [ 43.3,  75. ],
#        [  0. ,   0. ],
#        [  0. , 450. ],
#        [  0. , 100. ],
#        [  0. , 250. ],
#        [  0. , 600. ],
#        [  0. , 400. ],
#        [  0. , 550. ],
#        [  0. , 750. ]])

# %%
probe_number = 1 # number in registration
probe_type = 'neuronexus_A1_32_Poly2' # cambridge_neurotech_H7b

# %%
borders_table = pd.read_csv(os.path.join(directory, 'borders_table_{}.csv'.format(probe_number)), header=0, index_col=None)
probe_data = pd.read_csv(os.path.join(directory, 'probe_data_{}.csv'.format(probe_number)), header=0, index_col=None)

# %%
borders_table
# Out:
#     upperBorder  lowerBorder  acronym  \
# 0             0          200     MOs1
# 1           200          280   MOs2/3
# 2           280          850  ACAd2/3
# 3           850         1810    PL2/3
# 4          1810         1840   ILA2/3
# 5          1840         2090     ILA5
# 6          2090         2180     ILA5
# 7          2180         2220    ACAv5
# 8          2220         2230     ILA5
# 9          2230         2240    ACAv5
# 10         2240         2270     ILA5
# 11         2270         2630       DP
# 12         2630         2840      TTd
# 13         2840         3070      TTd
# 14         3070         3120      OLF
# 15         3120         3350      STR
#
#                                              name  avIndex
# 0                    Secondary motor area layer 1       26
# 1                  Secondary motor area layer 2/3       27
# 2   Anterior cingulate area dorsal part layer 2/3      229
# 3                        Prelimbic area layer 2/3      242
# 4                      Infralimbic area layer 2/3      249
# 5                        Infralimbic area layer 5      250
# 6                        Infralimbic area layer 5      250
# 7    Anterior cingulate area ventral part layer 5      236
# 8                        Infralimbic area layer 5      250
# 9    Anterior cingulate area ventral part layer 5      236
# 10                       Infralimbic area layer 5      250
# 11                         Dorsal peduncular area      411
# 12                       Taenia tecta dorsal part      400
# 13                       Taenia tecta dorsal part      400
# 14                                Olfactory areas      380
# 15                                       Striatum      572

# %%
probe_coordinates['pointList'][0][0][0][probe_number - 1][0]
# Out:
# array([[542, 431, 402],
#        [545, 396, 402],
#        [541, 359, 402],
#        [542, 325, 402],
#        [542, 285, 402],
#        [548, 385, 387],
#        [547, 358, 387],
#        [547, 336, 387],
#        [546, 302, 387],
#        [547, 274, 387],
#        [547, 258, 387],
#        [544, 356, 375],
#        [547, 337, 375],
#        [547, 314, 375],
#        [547, 290, 375],
#        [547, 259, 375],
#        [547, 239, 375],
#        [542, 323, 360],
#        [544, 299, 360],
#        [542, 276, 360],
#        [542, 249, 360],
#        [541, 225, 360],
#        [555, 301, 348],
#        [551, 275, 348],
#        [545, 246, 348],
#        [543, 223, 348],
#        [541, 194, 348],
#        [547, 329, 339],
#        [545, 303, 339],
#        [542, 275, 339],
#        [539, 247, 339],
#        [537, 224, 339],
#        [537, 197, 339],
#        [547, 367, 330],
#        [545, 336, 330],
#        [543, 305, 330],
#        [541, 276, 330],
#        [537, 246, 330],
#        [532, 216, 330],
#        [531, 185, 330]], dtype=uint16)

# %%
def get_probe(probe_number, probe_coordinates):
    probe_df = pd.DataFrame(probe_coordinates['pointList'][0][0][0][probe_number - 1][0], columns=['ML', 'DV', 'AP'])
    probe_df = probe_df * 10 # convert pixels to micorns
    return probe_df

# %%
probe_df = get_probe(probe_number, probe_coordinates)

# %%
def get_probe_best_fit_line(probe_df):
    points = Points(probe_df.to_numpy())
    line_fit = Line.best_fit(points)
    return line_fit

# %%
probe_best_fit_line = get_probe_best_fit_line(probe_df[['ML', 'DV', 'AP']])

# %%
def is_value_in_range(range_df, value):
    return range_df['upperBorder'] <= value < range_df['lowerBorder']

# %%
def add_acronym(df, borders_table):
    for i, row in df.iterrows():
        region = borders_table[borders_table[['lowerBorder', 'upperBorder']].apply(is_value_in_range, value=row['DV'], axis=1)]
        df.at[i, 'region_name'] = region['name'].item() if not region.empty else ''
        df.at[i, 'region_acronym'] = region['acronym'].item() if not region.empty else ''
    return df

# %%
probe_df = add_acronym(probe_df, borders_table)

# %%
probe_df
# Out:
#              ML           DV           AP  \
# 0   4753.587766  3780.067025  3525.723768
# 1   4779.899138  3473.101025  3525.723768
# 2   4744.817309  3148.594111  3525.723768
# 3   4753.587766  2850.398568  3525.723768
# 4   4753.587766  2499.580283  3525.723768
# 5   4806.210509  3376.625996  3394.166911
# 6   4797.440052  3139.823654  3394.166911
# 7   4797.440052  2946.873597  3394.166911
# 8   4788.669595  2648.678054  3394.166911
# 9   4797.440052  2403.105255  3394.166911
# 10  4797.440052  2262.777940  3394.166911
# 11  4771.128681  3122.282740  3288.921425
# 12  4797.440052  2955.644054  3288.921425
# 13  4797.440052  2753.923540  3288.921425
# 14  4797.440052  2543.432569  3288.921425
# 15  4797.440052  2271.548398  3288.921425
# 16  4797.440052  2096.139255  3288.921425
# 17  4753.587766  2832.857654  3157.364568
# 18  4771.128681  2622.366683  3157.364568
# 19  4753.587766  2420.646169  3157.364568
# 20  4753.587766  2183.843826  3157.364568
# 21  4744.817309  1973.352855  3157.364568
# 22  4867.603709  2639.907597  3052.119082
# 23  4832.521881  2411.875712  3052.119082
# 24  4779.899138  2157.532455  3052.119082
# 25  4762.358223  1955.811941  3052.119082
# 26  4744.817309  1701.468684  3052.119082
# 27  4797.440052  2885.480397  2973.184968
# 28  4779.899138  2657.448511  2973.184968
# 29  4753.587766  2411.875712  2973.184968
# 30  4727.276395  2166.302912  2973.184968
# 31  4709.735481  1964.582398  2973.184968
# 32  4709.735481  1727.780055  2973.184968
# 33  4797.440052  3218.757768  2894.250854
# 34  4779.899138  2946.873597  2894.250854
# 35  4762.358223  2674.989426  2894.250854
# 36  4744.817309  2420.646169  2894.250854
# 37  4709.735481  2157.532455  2894.250854
# 38  4665.883195  1894.418741  2894.250854
# 39  4657.112738  1622.534570  2894.250854
#
#                                      region_name region_acronym
# 0
# 1
# 2                                       Striatum            STR
# 3                       Taenia tecta dorsal part            TTd
# 4                         Dorsal peduncular area             DP
# 5
# 6                                       Striatum            STR
# 7                       Taenia tecta dorsal part            TTd
# 8                       Taenia tecta dorsal part            TTd
# 9                         Dorsal peduncular area             DP
# 10                      Infralimbic area layer 5           ILA5
# 11                                      Striatum            STR
# 12                      Taenia tecta dorsal part            TTd
# 13                      Taenia tecta dorsal part            TTd
# 14                        Dorsal peduncular area             DP
# 15                        Dorsal peduncular area             DP
# 16                      Infralimbic area layer 5           ILA5
# 17                      Taenia tecta dorsal part            TTd
# 18                        Dorsal peduncular area             DP
# 19                        Dorsal peduncular area             DP
# 20  Anterior cingulate area ventral part layer 5          ACAv5
# 21                      Infralimbic area layer 5           ILA5
# 22                      Taenia tecta dorsal part            TTd
# 23                        Dorsal peduncular area             DP
# 24                      Infralimbic area layer 5           ILA5
# 25                      Infralimbic area layer 5           ILA5
# 26                      Prelimbic area layer 2/3          PL2/3
# 27                      Taenia tecta dorsal part            TTd
# 28                      Taenia tecta dorsal part            TTd
# 29                        Dorsal peduncular area             DP
# 30                      Infralimbic area layer 5           ILA5
# 31                      Infralimbic area layer 5           ILA5
# 32                      Prelimbic area layer 2/3          PL2/3
# 33                                      Striatum            STR
# 34                      Taenia tecta dorsal part            TTd
# 35                      Taenia tecta dorsal part            TTd
# 36                        Dorsal peduncular area             DP
# 37                      Infralimbic area layer 5           ILA5
# 38                      Infralimbic area layer 5           ILA5
# 39                      Prelimbic area layer 2/3          PL2/3

# %%
def get_good_clusters_coordinates(clusters_df, channel_positions, channel_map):
    good_clusters_df = clusters_df.loc[(clusters_df['KSLabel'] == 'good') | (clusters_df['group'] == 'good'), ['ch', 'n_spikes']]
    probe_mapping_df = pd.DataFrame({'coordinates': list(map(tuple, channel_positions))}, index = channel_map.flatten())
    return good_clusters_df.join(probe_mapping_df, on='ch', how='left')

# %%
clusters_df = get_good_clusters_coordinates(clusters_data_df, channel_positions, channel_map)

# %%
clusters_df
# Out:
#     ch  n_spikes    coordinates
# id
# 3   15     73563   (0.0, 200.0)
# 8   30       247   (0.0, 550.0)
# 34   5      6664  (43.3, 125.0)
# 68   2     64061  (43.3, 475.0)
# 70   2      2091  (43.3, 475.0)

# %%
config = yaml.safe_load(open(r'C:\Users\shirahad\Documents\research\electrophysiology\analyze_electrophysiology_data\mapping\configuration\{}_config.yml'.format(probe_type))) # fix path

# %%
config

# %%
#active_probe_length = config['distance_between_channels_same_column'] * (config['num_of_channel_per_column'] - 1) + config['shift_between_columns']

# %%
def get_point_coordinates_on_probe(probe_points, cluster, shrinkage_factor):
    point = probe_points.to_point(cluster['coordinates'][1] * shrinkage_factor) # get the relevant point on the probe
    point[0] = point[0] + cluster['coordinates'][0] # shift the point on the ML axis (according to the columns on the probe)
    return point

# %%
clusters_points = clusters_df.apply(lambda x: get_point_coordinates_on_probe(probe_best_fit_line, x, probe_data['shrinkage_factor'].item()), axis=1)
clusters_points_df = pd.DataFrame(clusters_points.values.tolist(), index=clusters_points.index, columns=['ML', 'DV', 'AP'])
clusters_df = clusters_df.join(clusters_points_df, how='left')

# %%
clusters_df = add_acronym(clusters_df, borders_table)

# %%
clusters_df

# %%
# calculate probes registration points locations (from SHARP-TRACK) )in microns and rename columns to match brain_render demands
probe_df.columns = ['x', 'y', 'z', 'region_name', 'region_acronym']
fitted_probe_df = pd.DataFrame({'point': probe_best_fit_line.point, 'direction': probe_best_fit_line.direction})

# %%
clusters_coordinates_df = clusters_df[['ML', 'DV', 'AP', 'region_name', 'region_acronym']].copy()

# %%
clusters_coordinates_df.columns = ['x', 'y', 'z', 'region_name', 'region_acronym']

# %%
fitted_probe_df.to_csv(r'{}\files\probe_fitted_line_{}.csv'.format(directory, probe_number), sep=',', encoding='utf-8')
probe_df.to_csv(r'{}\files\sharp_track_probe_coordinates_{}.csv'.format(directory, probe_number), sep=',', encoding='utf-8', index_label='id')
